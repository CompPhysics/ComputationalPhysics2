# %% [markdown]
# # Stochastic Reconfiguration in Variational Monte Carlo
# ## Non-Interacting Bosons in a Harmonic Trap
#
# ---
#
# **Course**: FYS4411/9411 — Computational Physics II, Spring 2026
# **Author**: Morten Hjorth-Jensen
#
# ---
#
# ### Contents
#
# | Section | Topic |
# |---------|-------|
# | 1 | Physical model and trial wave function |
# | 2 | Imaginary-time evolution and variational projection |
# | 3 | Tangent-space expansion of the trial state |
# | 4 | Derivation of the SR linear system $S\,\delta\boldsymbol{\alpha}=-\delta\tau\,\boldsymbol{g}$ |
# | 5 | Logarithmic derivatives and the metric matrix $S$ |
# | 6 | The generalised force $\boldsymbol{g}$ and connection to natural gradient |
# | 7 | Regularisation and the SR algorithm |
# | 8 | Python implementation: VMC + SR for $N$ bosons in a harmonic trap |
# | 9 | Results, convergence, and comparison with gradient descent |
# | 10 | Exercises |

# %% [markdown]
# ---
# ## 1  Physical Model and Trial Wave Function
#
# ### 1.1  The Hamiltonian
#
# We study $N$ **non-interacting spinless bosons** confined in a $d$-dimensional isotropic harmonic oscillator trap.  In natural units ($\hbar = m = \omega = 1$) the Hamiltonian is
#
# $$H = \sum_{i=1}^{N}\left(-\frac{1}{2}\nabla_i^2 + \frac{1}{2}r_i^2\right),$$
#
# where $r_i = |\mathbf{r}_i|$ and $\nabla_i^2$ is the Laplacian acting on particle $i$.
#
# The exact ground-state energy is
#
# $$E_0 = \frac{Nd}{2},$$
#
# which follows immediately from the single-particle ground-state energy $d/2$ summed over all $N$ bosons.
#
# ### 1.2  Trial wave function
#
# We use a **Gaussian ansatz** with a single variational parameter $\alpha > 0$:
#
# $$\Psi_\alpha(\mathbf{r}_1,\ldots,\mathbf{r}_N) = \prod_{i=1}^{N} e^{-\alpha r_i^2} = \exp\!\left(-\alpha\sum_{i=1}^{N} r_i^2\right).$$
#
# This is the exact ground state when $\alpha = 1/2$, so the VMC optimiser should converge to $\alpha^* = 0.5$ starting from any positive initial value.
#
# The exact energy as a function of $\alpha$ is available analytically:
#
# $$E(\alpha) = \frac{Nd}{2}\left(\alpha + \frac{1}{4\alpha}\right),$$
#
# which has a minimum $E(1/2) = Nd/2$ at $\alpha=1/2$. This serves as a **benchmark** for the optimiser.
#
# ### 1.3  The logarithmic derivative
#
# The single variational parameter means $\boldsymbol{\alpha} = (\alpha)$ and there is one logarithmic derivative operator:
#
# $$O_1(\mathbf{x}) = \frac{\partial\ln\Psi_\alpha}{\partial\alpha} = -\sum_{i=1}^{N} r_i^2.$$
#
# The local energy (kinetic + potential, computed via the Laplacian) is
#
# $$E_\mathrm{loc}(\mathbf{x}) = \frac{H\Psi_\alpha}{\Psi_\alpha} = Nd\alpha + \left(\frac{1}{2} - 2\alpha^2\right)\sum_{i=1}^N r_i^2.$$

# %% [markdown]
# ---
# ## 2  Imaginary-Time Evolution and Variational Projection
#
# ### 2.1  Imaginary-time evolution
#
# The **exact** imaginary-time propagation of a state is
#
# $$|\Psi(\tau)\rangle = e^{-\tau H}|\Psi(0)\rangle.$$
#
# Expanding in energy eigenstates $H|n\rangle = E_n|n\rangle$:
#
# $$|\Psi(\tau)\rangle = \sum_n c_n\, e^{-\tau E_n}|n\rangle.$$
#
# For large $\tau$, provided $c_0 \neq 0$, the ground state dominates:
#
# $$|\Psi(\tau)\rangle \propto e^{-\tau E_0}|0\rangle.$$
#
# Imaginary-time propagation **filters out the ground state**.
#
# ### 2.2  Variational projection
#
# In VMC we restrict to the variational manifold
#
# $$\mathcal{M} = \left\{|\Psi(\boldsymbol{\alpha})\rangle \;\middle|\; \boldsymbol{\alpha}\in\mathbb{R}^p\right\}.$$
#
# An exact step $(1-\delta\tau\, H)|\Psi(\boldsymbol{\alpha})\rangle$ **does not remain in $\mathcal{M}$** for a general parametric family.  The **stochastic reconfiguration** idea is:
#
# 1. Apply one infinitesimal imaginary-time step.
# 2. Project the result back onto $\mathcal{M}$.
# 3. Read off the implied parameter update $\boldsymbol{\alpha}\to\boldsymbol{\alpha}+\delta\boldsymbol{\alpha}$.
#
# A norm-preserving form of the infinitesimal step is
#
# $$|\Psi_\mathrm{exact}'\rangle \approx \left[1-\delta\tau\bigl(H-E(\boldsymbol{\alpha})\bigr)\right]|\Psi(\boldsymbol{\alpha})\rangle,$$
#
# where subtracting $E(\boldsymbol{\alpha})$ removes the trivial component parallel to $|\Psi\rangle$ (it is orthogonal to $|\Psi\rangle$ to first order in $\delta\tau$, ensuring the update lies in the tangent space of projective Hilbert space).

# %% [markdown]
# ---
# ## 3  Tangent-Space Expansion and the Projection Principle
#
# ### 3.1  Taylor expansion of the variational state
#
# A first-order Taylor expansion of the variational state gives
#
# $$|\Psi(\boldsymbol{\alpha}+\delta\boldsymbol{\alpha})\rangle = |\Psi\rangle + \sum_k \delta\alpha_k |\Psi_k\rangle + \mathcal{O}(\delta\alpha^2),$$
#
# where the **tangent vectors** are
#
# $$|\Psi_k\rangle \equiv \frac{\partial}{\partial\alpha_k}|\Psi(\boldsymbol{\alpha})\rangle.$$
#
# ### 3.2  Minimising the mismatch
#
# Define the **mismatch vector**
#
# $$|\Delta\rangle = |\Psi_\mathrm{var}'\rangle - |\Psi_\mathrm{exact}'\rangle = \sum_k \delta\alpha_k|\Psi_k\rangle + \delta\tau(H-E)|\Psi\rangle.$$
#
# The SR update $\delta\boldsymbol{\alpha}$ minimises the squared norm
#
# $$\mathcal{D} = \langle\Delta|\Delta\rangle.$$
#
# Expanding and retaining terms of order $\delta\alpha\cdot\delta\tau$:
#
# $$\mathcal{D} = \sum_{ij}\delta\alpha_i\delta\alpha_j\langle\Psi_i|\Psi_j\rangle + 2\delta\tau\sum_i\delta\alpha_i\,\mathrm{Re}\langle\Psi_i|(H-E)|\Psi\rangle + \mathcal{O}(\delta\tau^2).$$
#
# ### 3.3  Stationarity condition
#
# Setting $\partial\mathcal{D}/\partial(\delta\alpha_i)=0$ yields the **projected imaginary-time equation** in the tangent basis:
#
# $$\sum_j \langle\Psi_i|\Psi_j\rangle\,\delta\alpha_j = -\delta\tau\,\mathrm{Re}\langle\Psi_i|(H-E)|\Psi\rangle.$$

# %% [markdown]
# ---
# ## 4  Derivation of the SR Linear System
#
# ### 4.1  Logarithmic derivative operators
#
# Let $x$ denote a many-body configuration and write the wave function as $\Psi(x)$.  Define the **logarithmic derivative operators**
#
# $$O_k(x) = \frac{1}{\Psi(x)}\frac{\partial\Psi(x)}{\partial\alpha_k} = \frac{\partial\ln\Psi(x)}{\partial\alpha_k}.$$
#
# Monte Carlo samples configurations with probability
#
# $$P(x) = \frac{|\Psi(x)|^2}{\langle\Psi|\Psi\rangle},$$
#
# so expectation values are estimated as sample means: $\langle A\rangle \approx \frac{1}{N_s}\sum_{\ell=1}^{N_s} A(x^{(\ell)})$.
#
# ### 4.2  The metric matrix $S$
#
# Working with the normalised state $|\overline{\Psi}\rangle = |\Psi\rangle/\sqrt{\langle\Psi|\Psi\rangle}$ and its tangent vectors, one finds
#
# $$S_{ij} = \langle O_i O_j\rangle - \langle O_i\rangle\langle O_j\rangle.$$
#
# This is the **covariance matrix of the logarithmic derivatives**.  It is symmetric positive semidefinite, and defines a Riemannian metric on $\mathcal{M}$:
#
# $$ds^2 = \sum_{ij} S_{ij}\,d\alpha_i\,d\alpha_j.$$
#
# ### 4.3  The generalised force $\boldsymbol{g}$
#
# The local energy is
#
# $$E_\mathrm{loc}(x) = \frac{(H\Psi)(x)}{\Psi(x)}.$$
#
# The right-hand side of the stationarity condition becomes
#
# $$g_i = \langle O_i E_\mathrm{loc}\rangle - \langle O_i\rangle\langle E_\mathrm{loc}\rangle,$$
#
# the covariance of the logarithmic derivative with the local energy.
#
# ### 4.4  The SR linear system
#
# Collecting everything:
#
# $$\boxed{S\,\delta\boldsymbol{\alpha} = -\delta\tau\,\boldsymbol{g}, \qquad \delta\boldsymbol{\alpha} = -\delta\tau\,S^{-1}\boldsymbol{g}.}$$
#
# **Comparison with gradient descent.** Ordinary gradient descent updates $\delta\boldsymbol{\alpha}_\mathrm{GD} = -\eta\boldsymbol{g}$, while SR uses $\delta\boldsymbol{\alpha}_\mathrm{SR} = -\eta\,S^{-1}\boldsymbol{g}$.  The inverse metric $S^{-1}$ rescales parameter directions according to the geometry of the wave-function manifold, giving better conditioning and a direct connection to imaginary-time evolution.

# %% [markdown]
# ---
# ## 4b  Fisher Information: Formal Derivation
#
# This section gives a self-contained derivation of the **Fisher information
# matrix**, proves that the SR metric $S$ is identical to the quantum Fisher
# information matrix (QFIM) for real wave functions, and shows step-by-step
# why the natural gradient and SR are the same update rule.
#
# ### 4b.1  Classical Fisher information
#
# Let $p(x;\boldsymbol{\alpha})$ be a parametric family of probability
# distributions over a sample space $\mathcal{X}$, labelled by
# $\boldsymbol{\alpha}\in\mathbb{R}^p$.  The **score function** is the
# gradient of the log-likelihood:
#
# $$s_k(x;\boldsymbol{\alpha})
# = \frac{\partial}{\partial\alpha_k}\ln p(x;\boldsymbol{\alpha}).$$
#
# **Lemma (zero mean of the score).**  Under mild regularity,
#
# $$\mathbb{E}_p[s_k] = \int p(x)\,\frac{\partial\ln p}{\partial\alpha_k}\,dx
# = \int \frac{\partial p}{\partial\alpha_k}\,dx
# = \frac{\partial}{\partial\alpha_k}\int p(x)\,dx = 0.$$
#
# The **Fisher information matrix** (FIM) is defined as the covariance matrix
# of the score:
#
# $$\boxed{F_{ij}(\boldsymbol{\alpha})
# = \mathbb{E}_p\!\left[s_i\,s_j\right]
# = \mathbb{E}_p\!\left[
# \frac{\partial\ln p}{\partial\alpha_i}\,
# \frac{\partial\ln p}{\partial\alpha_j}\right].}$$
#
# Because the score has zero mean, this equals the covariance:
#
# $$F_{ij} = \mathbb{E}_p[s_i s_j] - \mathbb{E}_p[s_i]\,\mathbb{E}_p[s_j]
# = \mathrm{Cov}_p(s_i, s_j).$$
#
# **Alternative form.**  Differentiating the normalisation $\int p\,dx=1$ twice
# and using integration by parts gives the equivalent Hessian form:
#
# $$F_{ij} = -\mathbb{E}_p\!\left[
# \frac{\partial^2\ln p}{\partial\alpha_i\,\partial\alpha_j}\right].$$
#
# **Positive semidefiniteness.**  For any vector $v\in\mathbb{R}^p$:
#
# $$v^\top F\,v
# = \mathbb{E}_p\!\left[\left(\sum_k v_k s_k\right)^2\right] \geq 0,$$
#
# with equality only if $\sum_k v_k\partial_{\alpha_k}\ln p = 0$ a.e., i.e.
# if $v$ points along a direction in which $p$ does not change.
#
# ### 4b.2  Fisher information as the curvature of KL divergence
#
# The Fisher information has a deep geometric meaning: it is the local
# **curvature of the Kullback–Leibler divergence** between nearby distributions.
#
# **Theorem.**  Let $\boldsymbol{\alpha}'=\boldsymbol{\alpha}+d\boldsymbol{\alpha}$.
# Then
#
# $$D_\mathrm{KL}\!\left(p(\cdot;\boldsymbol{\alpha})\,\|\,
# p(\cdot;\boldsymbol{\alpha}')\right)
# = \frac{1}{2}\sum_{ij}F_{ij}(\boldsymbol{\alpha})\,
# d\alpha_i\,d\alpha_j + \mathcal{O}(d\alpha^3).$$
#
# *Proof.*  Expand the KL divergence to second order:
#
# $$D_\mathrm{KL}(p\|p') = \mathbb{E}_p[\ln p - \ln p']
# = -\mathbb{E}_p\!\left[\sum_k d\alpha_k s_k
# + \frac{1}{2}\sum_{kl}d\alpha_k d\alpha_l
# \frac{\partial^2\ln p}{\partial\alpha_k\partial\alpha_l}\right]
# +\mathcal{O}(d\alpha^3).$$
#
# The first-order term vanishes because $\mathbb{E}_p[s_k]=0$.  The
# second-order term gives
#
# $$D_\mathrm{KL}(p\|p')
# = \frac{1}{2}\sum_{kl}d\alpha_k d\alpha_l\,
# \left(-\mathbb{E}_p\!\left[\frac{\partial^2\ln p}{\partial\alpha_k
# \partial\alpha_l}\right]\right)
# = \frac{1}{2}\,d\boldsymbol{\alpha}^\top F\,d\boldsymbol{\alpha}. \qquad\square$$
#
# Therefore $F$ is the **Riemannian metric** on the statistical manifold
# $\{p(\cdot;\boldsymbol{\alpha})\}$ induced by the KL divergence.  This metric is called the **Fisher–Rao metric**.

# %% [markdown]
# ### 4b.3  From classical to quantum Fisher information
#
# In VMC we do not work with an arbitrary parametric distribution.  Instead,
# the sampling distribution is
#
# $$p(x;\boldsymbol{\alpha})
# = \frac{|\Psi(x;\boldsymbol{\alpha})|^2}
# {\langle\Psi(\boldsymbol{\alpha})|\Psi(\boldsymbol{\alpha})\rangle}.$$
#
# **Score function for this distribution.**  Taking the log:
#
# $$\ln p(x;\boldsymbol{\alpha})
# = 2\ln|\Psi(x;\boldsymbol{\alpha})| - \ln Z(\boldsymbol{\alpha}),$$
#
# where $Z=\langle\Psi|\Psi\rangle$.  Differentiating:
#
# $$s_k(x;\boldsymbol{\alpha})
# = \frac{\partial\ln p}{\partial\alpha_k}
# = 2\,\mathrm{Re}\!
# \left[\frac{1}{\Psi(x)}\frac{\partial\Psi(x)}{\partial\alpha_k}\right]
# - \frac{\partial\ln Z}{\partial\alpha_k}.$$
#
# For **real** wave functions this becomes
#
# $$s_k(x) = 2\,O_k(x) - 2\langle O_k\rangle,$$
#
# where $O_k = \partial_{\alpha_k}\ln\Psi$ and we used
# $\frac{\partial\ln Z}{\partial\alpha_k}=2\langle O_k\rangle$
# (see derivation below).
#
# **Lemma** ($\partial_{\alpha_k}\ln Z = 2\langle O_k\rangle$):
#
# $$\frac{\partial Z}{\partial\alpha_k}
# = \int \frac{\partial|\Psi|^2}{\partial\alpha_k}\,dx
# = \int 2\,\Psi\frac{\partial\Psi}{\partial\alpha_k}\,dx
# = 2\int |\Psi|^2\,O_k\,dx
# = 2Z\langle O_k\rangle,$$
#
# so $\partial_{\alpha_k}\ln Z = 2\langle O_k\rangle$. $\square$
#
# **The quantum Fisher information matrix.**  Substituting the score into
# the FIM definition:
#
# $$F_{ij}
# = \mathbb{E}_p[s_i s_j]
# = \mathbb{E}_p\!\left[4(O_i-\langle O_i\rangle)(O_j-\langle O_j\rangle)\right]
# = 4\left(\langle O_i O_j\rangle - \langle O_i\rangle\langle O_j\rangle\right)
# = 4\,S_{ij}.$$
#
# $$\boxed{F_{ij} = 4\,S_{ij}.}$$
#
# The SR metric matrix $S$ is therefore **one quarter of the (classical)
# Fisher information matrix** of the distribution $p(x;\boldsymbol{\alpha})$.
#
# > **Remark on complex wave functions.**  For complex $\Psi$, the logarithmic
# > derivative is complex, the score becomes
# > $s_k = 2\,\mathrm{Re}[O_k] - 2\langle\mathrm{Re}[O_k]\rangle$,
# > and the QFIM generalises to
# > $S_{ij} = \mathrm{Re}[\langle O_i^* O_j\rangle
# > - \langle O_i^*\rangle\langle O_j\rangle]$.
# > The factor-of-four relation still holds.
#
# ### 4b.4  The Fubini–Study metric and the Bures metric
#
# In quantum mechanics there is a natural geometric structure on the space
# of pure states: the **Fubini–Study metric**
#
# $$ds^2_{\mathrm{FS}}
# = 1 - |\langle\overline{\Psi}(\boldsymbol{\alpha})
# |\overline{\Psi}(\boldsymbol{\alpha}')\rangle|^2.$$
#
# Expanding to second order in $d\boldsymbol{\alpha}$:
#
# $$ds^2_{\mathrm{FS}}
# = \sum_{ij}
# \left(\langle\partial_i\overline{\Psi}|\partial_j\overline{\Psi}\rangle
# - \langle\partial_i\overline{\Psi}|\overline{\Psi}\rangle
# \langle\overline{\Psi}|\partial_j\overline{\Psi}\rangle\right)
# d\alpha_i\,d\alpha_j.$$
#
# For real wave functions the imaginary parts vanish and one obtains
#
# $$ds^2_{\mathrm{FS}}
# = \sum_{ij} S_{ij}\,d\alpha_i\,d\alpha_j,$$
#
# confirming that $S$ is the pull-back of the Fubini–Study metric to
# the parameter space.  The same matrix governs:
#
# | Quantity | Expression |
# |---------|------------|
# | Fubini–Study squared distance | $ds^2_{\mathrm{FS}} = d\boldsymbol{\alpha}^\top S\,d\boldsymbol{\alpha}$ |
# | KL divergence between $p$ and $p'$ | $D_\mathrm{KL}\approx \frac{1}{2}d\boldsymbol{\alpha}^\top(4S)\,d\boldsymbol{\alpha}$ |
# | SR projected imaginary-time step | $S\,\delta\boldsymbol{\alpha}=-\delta\tau\,\boldsymbol{g}$ |
# | Natural gradient update | $\delta\boldsymbol{\alpha}\propto -F^{-1}\boldsymbol{g}=-\frac{1}{4}S^{-1}\boldsymbol{g}$ |

# %% [markdown]
# ### 4b.5  Formal derivation of the natural gradient
#
# Ordinary gradient descent minimises a loss $\mathcal{L}(\boldsymbol{\alpha})$
# by moving along the direction of steepest descent in the **Euclidean** metric
# on parameter space:
#
# $$\delta\boldsymbol{\alpha}_\mathrm{GD}
# = \operatorname*{arg\,min}_{\|\delta\boldsymbol{\alpha}\|\leq\epsilon}
# \mathcal{L}(\boldsymbol{\alpha}+\delta\boldsymbol{\alpha})
# \approx -\epsilon\,\frac{\boldsymbol{\nabla}\mathcal{L}}
# {\|\boldsymbol{\nabla}\mathcal{L}\|}.$$
#
# However, the **same physical update** can look very different in different
# parameterisations.  The natural gradient (Amari 1998) fixes this by using
# the intrinsic geometry of the model family.
#
# **Definition.**  The **natural gradient** is the steepest-descent direction
# in the Fisher–Rao metric:
#
# $$\widetilde{\nabla}\mathcal{L}
# = F(\boldsymbol{\alpha})^{-1}\,\nabla_{\boldsymbol{\alpha}}\mathcal{L}.$$
#
# The corresponding update is
# $\delta\boldsymbol{\alpha}_\mathrm{NG} = -\eta\,F^{-1}\boldsymbol{g}$.
#
# **Derivation via constrained optimisation.**
# Minimize the first-order Taylor expansion of $\mathcal{L}$ subject to a
# fixed KL-divergence step size $D_\mathrm{KL}(p(\boldsymbol{\alpha})
# \|p(\boldsymbol{\alpha}+\delta\boldsymbol{\alpha}))=\epsilon^2/2$:
#
# $$\min_{\delta\boldsymbol{\alpha}}\;\boldsymbol{g}^\top\delta\boldsymbol{\alpha}
# \quad\text{subject to}\quad
# \delta\boldsymbol{\alpha}^\top F\,\delta\boldsymbol{\alpha} = \epsilon^2.$$
#
# By Lagrange multipliers, introduce $\mu$ and differentiate:
#
# $$\frac{\partial}{\partial(\delta\boldsymbol{\alpha})}
# \left[\boldsymbol{g}^\top\delta\boldsymbol{\alpha}
# - \mu\left(\delta\boldsymbol{\alpha}^\top F\,
# \delta\boldsymbol{\alpha}-\epsilon^2\right)\right]
# = \boldsymbol{g} - 2\mu F\,\delta\boldsymbol{\alpha} = \bm{0},$$
#
# giving
#
# $$\delta\boldsymbol{\alpha} = \frac{1}{2\mu}F^{-1}\boldsymbol{g}.$$
#
# The sign is fixed by requiring $\mathcal{L}$ to decrease:
#
# $$\boxed{\delta\boldsymbol{\alpha}_\mathrm{NG} = -\eta\,F^{-1}\boldsymbol{g}.}$$
#
# **Reparameterisation covariance.**  Under a smooth invertible change
# $\boldsymbol{\beta}=f(\boldsymbol{\alpha})$, the FIM transforms as a
# $(0,2)$ tensor:
#
# $$F^{(\beta)}_{ij}
# = \sum_{kl}\frac{\partial\alpha_k}{\partial\beta_i}
# F^{(\alpha)}_{kl}\frac{\partial\alpha_l}{\partial\beta_j}
# = (J^\top F^{(\alpha)} J)_{ij},$$
#
# where $J_{ki}=\partial\alpha_k/\partial\beta_i$ is the Jacobian.  The gradient
# transforms as a $(1,0)$ tensor:
# $g^{(\beta)}_i = \sum_k g^{(\alpha)}_k J_{ki}$.  Therefore:
#
# $$\delta\boldsymbol{\beta}_\mathrm{NG}
# = -\eta\,(F^{(\beta)})^{-1}\boldsymbol{g}^{(\beta)}
# = -\eta\,(J^\top F^{(\alpha)} J)^{-1}J^\top\boldsymbol{g}^{(\alpha)}
# = J^{-1}\delta\boldsymbol{\alpha}_\mathrm{NG}.$$
#
# The update in $\boldsymbol{\beta}$-space is exactly the push-forward of the
# update in $\boldsymbol{\alpha}$-space.  **The natural gradient is
# reparameterisation-covariant; plain gradient descent is not.**
#
# ### 4b.6  Connecting natural gradient to SR
#
# We have established:
#
# $$F_{ij} = 4S_{ij}
# \quad\Longrightarrow\quad
# F^{-1} = \frac{1}{4}S^{-1}.$$
#
# The natural gradient update for the energy $\mathcal{L}=E(\boldsymbol{\alpha})$
# is therefore
#
# $$\delta\boldsymbol{\alpha}_\mathrm{NG}
# = -\eta\,F^{-1}\boldsymbol{g}
# = -\frac{\eta}{4}\,S^{-1}\boldsymbol{g}.$$
#
# Identifying $\eta/4$ with $\delta\tau$ gives exactly the SR update:
#
# $$\delta\boldsymbol{\alpha}_\mathrm{SR}
# = -\delta\tau\,S^{-1}\boldsymbol{g}
# \equiv \delta\boldsymbol{\alpha}_\mathrm{NG}.$$
#
# **Summary of the three-way equivalence:**
#
# $$\underbrace{S\,\delta\boldsymbol{\alpha}=-\delta\tau\,\boldsymbol{g}}_{\text{projected imaginary-time (SR)}}
# \;\iff\;
# \underbrace{\delta\boldsymbol{\alpha}=-\delta\tau\,S^{-1}\boldsymbol{g}}_{\text{natural gradient on }\mathcal{M}}
# \;\iff\;
# \underbrace{\delta\boldsymbol{\alpha}=-\tfrac{\delta\tau}{4}\,F^{-1}\boldsymbol{g}}_{\text{natural gradient w.r.t. }p(x;\boldsymbol{\alpha})}.$$
#
# The three descriptions are the same update in different languages:
# quantum mechanics (imaginary-time projection), information geometry
# (steepest descent on the statistical manifold), and optimisation theory
# (natural gradient).
#
# ### 4b.7  Cramér–Rao bound and Fisher information
#
# The Fisher information also controls estimation uncertainty through
# the **Cramér–Rao bound**: for any unbiased estimator
# $\hat{\boldsymbol{\alpha}}$ of $\boldsymbol{\alpha}$ from $N_s$ i.i.d.
# samples,
#
# $$\mathrm{Cov}(\hat{\boldsymbol{\alpha}})
# \succeq \frac{1}{N_s}F(\boldsymbol{\alpha})^{-1}.$$
#
# In VMC this means the **statistical noise on the parameter update is bounded
# below by $(N_s F)^{-1}$**. Directions in which $F$ is small (flat directions of
# the statistical manifold) are both hard to estimate and
# unnecessary to update — precisely the directions damped by regularisation.
# This gives a principled interpretation of the regularisation
# $(S+\lambda I)^{-1}$: it replaces the ill-conditioned $S^{-1}$ with a
# smoother operator that respects the Cramér–Rao limit.

# %% [markdown]
# ---
# ## 5  Natural Gradient, Regularisation, and the SR Algorithm
#
# ### 5.1  SR as the natural gradient
#
# Because $S$ is the Riemannian metric on $\mathcal{M}$, the steepest-descent direction in that metric is
#
# $$\delta\boldsymbol{\alpha} \propto -S^{-1}\boldsymbol{g},$$
#
# which is precisely the **natural gradient** update (Amari 1998).  SR therefore inherits all the favourable properties of the natural gradient:
#
# - Reduced sensitivity to redundant parameterisations.
# - Better conditioning than plain gradient descent.
# - Covariance under parameter reparameterisation.
#
# ### 5.2  Regularisation
#
# In practice $S$ is estimated from a finite Monte Carlo sample and may be singular or ill-conditioned.  The standard fix is **diagonal regularisation**:
#
# $$S \to S + \lambda I, \qquad \lambda > 0.$$
#
# The regularised system
#
# $$(S+\lambda I)\,\delta\boldsymbol{\alpha} = -\delta\tau\,\boldsymbol{g}$$
#
# - stabilises the matrix inversion,
# - damps directions with negligible Fisher information,
# - interpolates between SR ($\lambda\to 0$) and plain gradient descent ($\lambda\to\infty$).
#
# ### 5.3  SR algorithm summary
#
# At each iteration:
#
# 1. Sample $N_s$ configurations $x^{(\ell)}$ from $P(x)=|\Psi(x)|^2/\langle\Psi|\Psi\rangle$ using Metropolis–Hastings.
# 2. Compute logarithmic derivatives $O_k(x^{(\ell)})$ and local energies $E_\mathrm{loc}(x^{(\ell)})$ at each configuration.
# 3. Estimate
# $$S_{ij} = \langle O_i O_j\rangle - \langle O_i\rangle\langle O_j\rangle, \qquad g_i = \langle O_i E_\mathrm{loc}\rangle - \langle O_i\rangle\langle E_\mathrm{loc}\rangle.$$
# 4. Solve $(S+\lambda I)\,\delta\boldsymbol{\alpha} = -\delta\tau\,\boldsymbol{g}$.
# 5. Update $\boldsymbol{\alpha} \leftarrow \boldsymbol{\alpha} + \delta\boldsymbol{\alpha}$.

# %% [markdown]
# ---
# ## 6  Python Implementation
#
# We now implement the full VMC + SR algorithm in pure NumPy.  Every quantity that appears in the theory above — the metric matrix $S$, the force vector $\boldsymbol{g}$, the Metropolis sampler, and the local energy — is computed explicitly so that the code mirrors the mathematics one-to-one.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.linalg import solve
import warnings
warnings.filterwarnings('ignore')

# Reproducibility
np.random.seed(42)

plt.rcParams.update({
    'figure.dpi': 120,
    'font.size': 12,
    'axes.labelsize': 13,
    'axes.titlesize': 14,
    'lines.linewidth': 2.0,
    'axes.grid': True,
    'grid.alpha': 0.35,
})
print(f'NumPy {np.__version__}  ready.')

# %% [markdown]
# ### 6.1  Physical model
#
# The trial wave function and all derived quantities are defined here.  The code is written for $N$ particles in $d$ dimensions with a single variational parameter $\alpha$.

# %%
# ── Physical parameters ───────────────────────────────────────────────────────
N_PARTICLES = 5    # number of non-interacting bosons
DIM         = 3    # spatial dimension
EXACT_E0    = N_PARTICLES * DIM / 2.0   # exact ground-state energy Nd/2
EXACT_ALPHA = 0.5                        # variational minimum


# ── Trial wave function  Ψ_α(x) = exp(-α Σ r_i^2) ───────────────────────────
def log_psi(x, alpha):
    """Log of the trial wave function (unnormalised).

    Parameters
    ----------
    x     : ndarray (N, d)  -- particle positions
    alpha : float           -- variational parameter

    Returns
    -------
    float : ln Psi_alpha(x) = -alpha * sum_i |r_i|^2
    """
    return -alpha * np.sum(x**2)


def psi(x, alpha):
    """Trial wave function value."""
    return np.exp(log_psi(x, alpha))


# ── Local energy  E_loc(x) = (H Psi)(x) / Psi(x) ────────────────────────────
def local_energy(x, alpha):
    """Analytic local energy for the Gaussian ansatz.

    For Psi = exp(-alpha * sum r_i^2):
        Kinetic: -1/2 nabla^2 Psi / Psi = alpha*d*N - 2*alpha^2 * sum r_i^2
        Potential: 1/2 * sum r_i^2

    So  E_loc = N*d*alpha + (1/2 - 2*alpha^2) * sum r_i^2
    """
    r2_total = np.sum(x**2)          # sum_i |r_i|^2
    N, d     = x.shape
    return N * d * alpha + (0.5 - 2.0 * alpha**2) * r2_total


# ── Logarithmic derivative  O_1(x) = d ln Psi / d alpha ──────────────────────
def log_deriv(x):
    """Logarithmic derivative O_1(x) = d ln Psi_alpha / d alpha = -sum r_i^2.

    (Independent of alpha for this ansatz.)
    """
    return -np.sum(x**2)   # scalar for the single-parameter case


# ── Exact analytic energy  E(alpha) = N*d/2 * (alpha + 1/(4*alpha)) ──────────
def exact_energy(alpha, N=N_PARTICLES, d=DIM):
    """Analytic expectation value of H for the Gaussian trial state."""
    return N * d / 2.0 * (alpha + 1.0 / (4.0 * alpha))


# Quick sanity check
x_test = np.zeros((N_PARTICLES, DIM))
print(f'N = {N_PARTICLES} bosons, d = {DIM} dimensions')
print(f'Exact ground-state energy     E_0     = {EXACT_E0:.4f}')
print(f'Exact minimum of E(alpha)     alpha*  = {EXACT_ALPHA:.4f}')
print(f'E_loc(0, alpha=0.5)           = {local_energy(x_test, 0.5):.4f}  (should be 0)')
print(f'E_loc(0, alpha=1.0)           = {local_energy(x_test, 1.0):.4f}  (should be 0)')
print(f'Analytic E(alpha=0.5)         = {exact_energy(0.5):.4f}  (should be {EXACT_E0:.4f})')
print(f'Analytic E(alpha=1.0)         = {exact_energy(1.0):.4f}')

# %% [markdown]
# ### 6.2  Metropolis–Hastings sampler
#
# We sample configurations $x$ from
#
# $$P(x) = \frac{|\Psi_\alpha(x)|^2}{\langle\Psi_\alpha|\Psi_\alpha\rangle}$$
#
# using the **Metropolis–Hastings algorithm** with a symmetric Gaussian proposal $x' = x + \delta\,\xi$, $\xi\sim\mathcal{N}(0,1)$.  The acceptance ratio simplifies to
#
# $$A(x'|x) = \min\!\left(1,\frac{|\Psi(x')|^2}{|\Psi(x)|^2}\right) = \min\!\left(1, e^{2[\ln\Psi(x')-\ln\Psi(x)]}\right).$$
#
# The step size $\delta$ is tuned to achieve an acceptance rate near 50%.

# %%
def metropolis_sampler(alpha, N_samples, step_size=0.5,
                       N_equil=2000, N_particles=N_PARTICLES, dim=DIM):
    """Metropolis-Hastings sampler for |Psi_alpha(x)|^2.

    Parameters
    ----------
    alpha       : float   -- variational parameter
    N_samples   : int     -- number of samples to collect after equilibration
    step_size   : float   -- Gaussian proposal width delta
    N_equil     : int     -- equilibration steps (discarded)
    N_particles : int     -- number of particles
    dim         : int     -- spatial dimension

    Returns
    -------
    samples     : ndarray (N_samples, N_particles, dim)
    accept_rate : float   -- fraction of accepted moves
    """
    # Initialise at random positions
    x_curr    = np.random.randn(N_particles, dim) * 0.5
    lp_curr   = log_psi(x_curr, alpha)   # log |Psi(x)|  (not squared; we compare 2*diff)

    samples   = np.zeros((N_samples, N_particles, dim))
    n_accept  = 0
    n_total   = N_equil + N_samples

    for step in range(n_total):
        # Gaussian proposal: move all particles simultaneously
        x_prop  = x_curr + step_size * np.random.randn(N_particles, dim)
        lp_prop = log_psi(x_prop, alpha)

        # Metropolis acceptance:  accept with prob min(1, |Psi(x')|^2 / |Psi(x)|^2)
        # = min(1, exp(2*(lp_prop - lp_curr)))
        log_ratio = 2.0 * (lp_prop - lp_curr)
        if np.log(np.random.uniform()) < log_ratio:
            x_curr  = x_prop
            lp_curr = lp_prop
            if step >= N_equil:
                n_accept += 1

        if step >= N_equil:
            samples[step - N_equil] = x_curr

    accept_rate = n_accept / N_samples
    return samples, accept_rate


# Test the sampler at the exact minimum
test_samples, test_acc = metropolis_sampler(0.5, N_samples=5000, step_size=0.5)
E_test = np.mean([local_energy(s, 0.5) for s in test_samples])
print(f'Sampler test at alpha=0.5:')
print(f'  Acceptance rate  : {test_acc:.3f}  (target ~0.50)')
print(f'  <E_loc>          : {E_test:.5f}  (exact: {EXACT_E0:.5f})')

# %% [markdown]
# ### 6.3  VMC energy and gradient estimator
#
# Given samples from $P(x)$ we estimate:
#
# $$\langle E\rangle \approx \frac{1}{N_s}\sum_{\ell=1}^{N_s} E_\mathrm{loc}(x^{(\ell)}),$$
#
# $$S_{ij} \approx \frac{1}{N_s}\sum_\ell O_i(x^{(\ell)})O_j(x^{(\ell)}) - \bar{O}_i\bar{O}_j,$$
#
# $$g_i \approx \frac{1}{N_s}\sum_\ell O_i(x^{(\ell)})E_\mathrm{loc}(x^{(\ell)}) - \bar{O}_i\bar{E},$$
#
# where $\bar{O}_i = \frac{1}{N_s}\sum_\ell O_i(x^{(\ell)})$ and $\bar{E} = \frac{1}{N_s}\sum_\ell E_\mathrm{loc}(x^{(\ell)})$.
#
# For the single-parameter Gaussian ansatz, $S$ and $\boldsymbol{g}$ reduce to scalar quantities:
#
# $$S_{11} = \langle O_1^2\rangle - \langle O_1\rangle^2, \qquad g_1 = \langle O_1 E_\mathrm{loc}\rangle - \langle O_1\rangle\langle E_\mathrm{loc}\rangle.$$

# %%
def vmc_estimate(alpha, N_samples=4000, step_size=0.5):
    """VMC energy and SR ingredients for a given alpha.

    Returns
    -------
    E_mean   : float  -- <E_loc>
    E_std    : float  -- standard error on <E_loc>
    S_mat    : float  -- S matrix (1x1 for single parameter)
    g_vec    : float  -- force vector g (scalar here)
    acc_rate : float  -- Metropolis acceptance rate
    """
    samples, acc_rate = metropolis_sampler(alpha, N_samples,
                                           step_size=step_size)
    Ns = len(samples)

    # Evaluate O_k and E_loc at each sampled configuration
    O  = np.array([log_deriv(s)    for s in samples])   # shape (Ns,)
    EL = np.array([local_energy(s, alpha) for s in samples])  # shape (Ns,)

    # Mean values
    O_mean  = O.mean()    # <O_1>
    E_mean  = EL.mean()   # <E_loc>
    E_std   = EL.std() / np.sqrt(Ns)   # standard error

    # Metric matrix  S_11 = <O^2> - <O>^2  (covariance of log-derivatives)
    S_mat = (O**2).mean() - O_mean**2

    # Force vector  g_1 = <O * E_loc> - <O> * <E_loc>  (covariance with local energy)
    g_vec = (O * EL).mean() - O_mean * E_mean

    return E_mean, E_std, S_mat, g_vec, acc_rate


# Scan alpha to verify analytic energy curve
alphas_scan = np.linspace(0.2, 1.2, 30)
E_vmc   = []
E_exact = [exact_energy(a) for a in alphas_scan]

for a in alphas_scan:
    E_m, _, _, _, _ = vmc_estimate(a, N_samples=3000)
    E_vmc.append(E_m)

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(alphas_scan, E_exact, color='steelblue', lw=2.5, label='Analytic $E(\\alpha)$')
ax.scatter(alphas_scan, E_vmc,  color='tomato',    s=40,   label='VMC estimate', zorder=5)
ax.axvline(EXACT_ALPHA, color='k', ls=':', lw=1.5,
           label=rf'$\alpha^*={EXACT_ALPHA}$')
ax.axhline(EXACT_E0,    color='grey', ls='-.', lw=1.2,
           label=rf'$E_0={EXACT_E0:.1f}$')
ax.set_xlabel(r'Variational parameter $\alpha$')
ax.set_ylabel(r'Energy $\langle E \rangle$')
ax.set_title(rf'VMC energy vs $\alpha$: $N={N_PARTICLES}$ bosons, $d={DIM}$')
ax.legend(fontsize=10)
plt.tight_layout(); plt.show()
print('VMC energy curve matches analytic result.')

# %% [markdown]
# ### 6.4  Stochastic Reconfiguration optimiser
#
# The SR update for the single-parameter case reduces to
#
# $$\delta\alpha = -\delta\tau\,\frac{g_1}{S_{11}+\lambda},$$
#
# which is just a rescaled gradient step with a geometry-aware learning rate $1/(S_{11}+\lambda)$.  For multiple parameters it generalises to the full linear system $(S+\lambda I)\,\delta\boldsymbol{\alpha}=-\delta\tau\,\boldsymbol{g}$, which is solved with `scipy.linalg.solve`.
#
# We also implement plain **gradient descent** (GD) for comparison:
#
# $$\delta\alpha_\mathrm{GD} = -\eta\,g_1.$$

# %%
def sr_optimizer(
    alpha_init,
    n_iterations  = 200,
    dtau          = 0.05,    # SR step size  delta_tau
    lam           = 1e-3,    # SR regularisation  lambda
    N_samples     = 3000,    # MC samples per iteration
    step_size     = 0.5,     # Metropolis step size
    verbose       = True,
):
    """Stochastic Reconfiguration optimiser for a single variational parameter.

    At each iteration it:
    1. Runs a Metropolis-Hastings Markov chain to sample |Psi_alpha|^2.
    2. Estimates S_11 (covariance of log-derivatives) and g_1 (covariance
       of log-derivative with local energy) from the samples.
    3. Solves (S_11 + lambda) * d_alpha = -dtau * g_1.
    4. Updates alpha <- alpha + d_alpha.

    Parameters
    ----------
    alpha_init    : float  -- starting value of alpha
    n_iterations  : int    -- number of SR steps
    dtau          : float  -- imaginary-time step (SR learning rate)
    lam           : float  -- diagonal regularisation for S
    N_samples     : int    -- Metropolis samples per iteration
    step_size     : float  -- Metropolis proposal width
    verbose       : bool   -- print progress every 20 steps

    Returns
    -------
    history : dict with keys 'alpha', 'energy', 'energy_std', 'S', 'g',
              'dalpha', 'accept_rate'
    """
    alpha   = float(alpha_init)
    history = {
        'alpha'      : [],
        'energy'     : [],
        'energy_std' : [],
        'S'          : [],
        'g'          : [],
        'dalpha'     : [],
        'accept_rate': [],
    }

    for it in range(n_iterations):
        # ── Step 1–3: VMC estimation ──────────────────────────────────────────
        E_mean, E_std, S_11, g_1, acc = vmc_estimate(
            alpha, N_samples=N_samples, step_size=step_size)

        # ── Step 4: SR update  d_alpha = -dtau * g_1 / (S_11 + lambda) ──────
        # (Generalises to:  (S + lambda*I) d_alpha = -dtau * g  for p>1)
        d_alpha = -dtau * g_1 / (S_11 + lam)

        # ── Step 5: parameter update ──────────────────────────────────────────
        alpha = max(alpha + d_alpha, 1e-4)   # keep alpha > 0

        # Record
        history['alpha']      .append(alpha)
        history['energy']     .append(E_mean)
        history['energy_std'] .append(E_std)
        history['S']          .append(S_11)
        history['g']          .append(g_1)
        history['dalpha']     .append(d_alpha)
        history['accept_rate'].append(acc)

        if verbose and (it % 20 == 0 or it == n_iterations - 1):
            print(f'  Iter {it+1:4d}/{n_iterations}  '
                  f'alpha={alpha:.6f}  '
                  f'E={E_mean:.5f} +/- {E_std:.5f}  '
                  f'S={S_11:.4e}  g={g_1:.4e}  '
                  f'acc={acc:.3f}')

    return {k: np.array(v) for k, v in history.items()}


print('SR optimiser defined. Running optimisation...')

# %%
def gd_optimizer(
    alpha_init,
    n_iterations = 200,
    eta          = 0.05,    # GD learning rate
    N_samples    = 3000,
    step_size    = 0.5,
    verbose      = True,
):
    """Plain gradient descent:  delta_alpha = -eta * g_1.

    Identical setup to sr_optimizer but without the S-matrix rescaling.
    """
    alpha   = float(alpha_init)
    history = {
        'alpha'      : [],
        'energy'     : [],
        'energy_std' : [],
        'g'          : [],
    }

    for it in range(n_iterations):
        E_mean, E_std, S_11, g_1, acc = vmc_estimate(
            alpha, N_samples=N_samples, step_size=step_size)

        # Plain gradient step (no S^{-1} rescaling)
        d_alpha = -eta * g_1
        alpha   = max(alpha + d_alpha, 1e-4)

        history['alpha']      .append(alpha)
        history['energy']     .append(E_mean)
        history['energy_std'] .append(E_std)
        history['g']          .append(g_1)

        if verbose and (it % 20 == 0 or it == n_iterations - 1):
            print(f'  Iter {it+1:4d}/{n_iterations}  '
                  f'alpha={alpha:.6f}  '
                  f'E={E_mean:.5f} +/- {E_std:.5f}')

    return {k: np.array(v) for k, v in history.items()}

print('GD optimiser defined.')

# %% [markdown]
# ### 6.5  Running the SR optimiser
#
# We start from $\alpha_0 = 0.8$ (displaced from the exact minimum $\alpha^*=0.5$) and run 150 SR iterations.

# %%
ALPHA_INIT   = 0.8    # starting point (far from alpha* = 0.5)
N_ITER       = 150
N_SAMPLES    = 4000

print('=' * 65)
print('  Stochastic Reconfiguration optimisation')
print(f'  Starting alpha = {ALPHA_INIT},  target alpha* = {EXACT_ALPHA}')
print('=' * 65)
hist_sr = sr_optimizer(
    alpha_init   = ALPHA_INIT,
    n_iterations = N_ITER,
    dtau         = 0.05,
    lam          = 1e-3,
    N_samples    = N_SAMPLES,
    step_size    = 0.5,
    verbose      = True,
)

# %%
print('=' * 65)
print('  Gradient descent optimisation  (for comparison)')
print(f'  Starting alpha = {ALPHA_INIT}')
print('=' * 65)
hist_gd = gd_optimizer(
    alpha_init   = ALPHA_INIT,
    n_iterations = N_ITER,
    eta          = 0.05,
    N_samples    = N_SAMPLES,
    step_size    = 0.5,
    verbose      = True,
)

# %% [markdown]
# ---
# ## 7  Results and Analysis
#
# ### 7.1  Convergence of $\alpha$ and the energy

# %%
iters = np.arange(1, N_ITER + 1)

fig = plt.figure(figsize=(15, 11))
gs  = gridspec.GridSpec(3, 2, hspace=0.50, wspace=0.35)

# ── Panel A: alpha vs iteration ───────────────────────────────────────────────
ax = fig.add_subplot(gs[0, 0])
ax.plot(iters, hist_sr['alpha'], color='steelblue', lw=2,   label='SR')
ax.plot(iters, hist_gd['alpha'], color='tomato',    lw=2, ls='--', label='GD')
ax.axhline(EXACT_ALPHA, color='k', ls=':', lw=1.5,
           label=rf'$\alpha^*={EXACT_ALPHA}$')
ax.set_xlabel('Iteration'); ax.set_ylabel(r'$\alpha$')
ax.set_title(r'Convergence of variational parameter $\alpha$')
ax.legend(fontsize=10)

# ── Panel B: energy vs iteration ─────────────────────────────────────────────
ax = fig.add_subplot(gs[0, 1])
ax.plot(iters, hist_sr['energy'], color='steelblue', lw=2,   label='SR')
ax.fill_between(iters,
    hist_sr['energy'] - hist_sr['energy_std'],
    hist_sr['energy'] + hist_sr['energy_std'],
    alpha=0.20, color='steelblue')
ax.plot(iters, hist_gd['energy'], color='tomato',    lw=2, ls='--', label='GD')
ax.fill_between(iters,
    hist_gd['energy'] - hist_gd['energy_std'],
    hist_gd['energy'] + hist_gd['energy_std'],
    alpha=0.20, color='tomato')
ax.axhline(EXACT_E0, color='k', ls=':', lw=1.5,
           label=rf'$E_0={EXACT_E0:.2f}$')
ax.set_xlabel('Iteration'); ax.set_ylabel(r'$\langle E \rangle$')
ax.set_title('Energy convergence (shading = 1 s.e.)')
ax.legend(fontsize=10)

# ── Panel C: |E - E0| on log scale ───────────────────────────────────────────
ax = fig.add_subplot(gs[1, 0])
ax.semilogy(iters, np.abs(hist_sr['energy'] - EXACT_E0),
            color='steelblue', lw=2,   label='SR')
ax.semilogy(iters, np.abs(hist_gd['energy'] - EXACT_E0),
            color='tomato',    lw=2, ls='--', label='GD')
ax.set_xlabel('Iteration'); ax.set_ylabel(r'$|\langle E\rangle - E_0|$')
ax.set_title('Energy error (log scale)')
ax.legend(fontsize=10)

# ── Panel D: S matrix diagonal vs iteration ───────────────────────────────────
ax = fig.add_subplot(gs[1, 1])
ax.plot(iters, hist_sr['S'], color='darkorchid', lw=2)
ax.set_xlabel('Iteration')
ax.set_ylabel(r'$S_{11} = \mathrm{Cov}(O_1, O_1)$')
ax.set_title(r'SR metric matrix element $S_{11}$ vs iteration')

# ── Panel E: force g vs iteration ────────────────────────────────────────────
ax = fig.add_subplot(gs[2, 0])
ax.plot(iters, hist_sr['g'], color='steelblue',  lw=2, label='SR $g_1$')
ax.plot(iters, hist_gd['g'], color='tomato',     lw=2, ls='--', label='GD $g_1$')
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.set_xlabel('Iteration')
ax.set_ylabel(r'$g_1 = \mathrm{Cov}(O_1, E_\mathrm{loc})$')
ax.set_title('Force vector $g_1$ (should vanish at minimum)')
ax.legend(fontsize=10)

# ── Panel F: effective learning rate 1/(S + lambda) ──────────────────────────
lam = 1e-3
ax = fig.add_subplot(gs[2, 1])
ax.plot(iters, 1.0 / (hist_sr['S'] + lam),
        color='darkorchid', lw=2,
        label=r'SR effective LR $1/(S_{11}+\lambda)$')
ax.axhline(0.05/np.mean(hist_sr['S'][:10] + lam), color='grey', ls=':',
           label='GD LR (constant)')
ax.set_xlabel('Iteration')
ax.set_ylabel(r'Effective learning rate')
ax.set_title(r'SR adaptive learning rate vs GD fixed rate')
ax.legend(fontsize=9)

fig.suptitle(
    rf'VMC + SR for $N={N_PARTICLES}$ non-interacting bosons in $d={DIM}$D'
    rf' harmonic trap  ($\alpha_0={ALPHA_INIT}$)',
    fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %%
# ── Final-iteration statistics ────────────────────────────────────────────────
avg_last = 20   # average over the last 20 iterations

alpha_sr_final = hist_sr['alpha'][-avg_last:].mean()
E_sr_final     = hist_sr['energy'][-avg_last:].mean()
E_sr_err       = hist_sr['energy'][-avg_last:].std() / np.sqrt(avg_last)

alpha_gd_final = hist_gd['alpha'][-avg_last:].mean()
E_gd_final     = hist_gd['energy'][-avg_last:].mean()
E_gd_err       = hist_gd['energy'][-avg_last:].std() / np.sqrt(avg_last)

print('=' * 65)
print('  FINAL RESULTS  (average over last 20 iterations)')
print('=' * 65)
print(f'  Exact alpha*        = {EXACT_ALPHA:.6f}')
print(f'  Exact E0            = {EXACT_E0:.6f}')
print()
print(f'  SR  alpha           = {alpha_sr_final:.6f}  '
      f'(error: {abs(alpha_sr_final - EXACT_ALPHA):.2e})')
print(f'  SR  <E>             = {E_sr_final:.6f} +/- {E_sr_err:.2e}  '
      f'(error: {abs(E_sr_final - EXACT_E0):.2e})')
print()
print(f'  GD  alpha           = {alpha_gd_final:.6f}  '
      f'(error: {abs(alpha_gd_final - EXACT_ALPHA):.2e})')
print(f'  GD  <E>             = {E_gd_final:.6f} +/- {E_gd_err:.2e}  '
      f'(error: {abs(E_gd_final - EXACT_E0):.2e})')

# %% [markdown]
# ### 7.2  Sensitivity to the regularisation parameter $\lambda$
#
# The SR update is $\delta\alpha = -\delta\tau\,g_1/(S_{11}+\lambda)$.  For large $\lambda$ this reduces to plain gradient descent; for small $\lambda$ the natural-gradient rescaling is fully active.  We run SR for several values of $\lambda$ and compare convergence speed.

# %%
lambdas    = [1e-4, 1e-3, 1e-2, 1e-1]
colors_lam = ['#1a6faf', '#3aaa35', '#e8721c', '#aa1a2a']
hist_lam   = {}

for lam in lambdas:
    print(f'  Running SR with lambda = {lam:.0e} ...')
    hist_lam[lam] = sr_optimizer(
        alpha_init   = ALPHA_INIT,
        n_iterations = 100,
        dtau         = 0.05,
        lam          = lam,
        N_samples    = 3000,
        verbose      = False,
    )

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

ax = axes[0]
for lam, col in zip(lambdas, colors_lam):
    ax.plot(hist_lam[lam]['alpha'], color=col, lw=1.8,
            label=rf'$\lambda={lam:.0e}$')
ax.axhline(EXACT_ALPHA, color='k', ls=':', lw=1.5, label=r'$\alpha^*$')
ax.set_xlabel('Iteration'); ax.set_ylabel(r'$\alpha$')
ax.set_title(r'$\alpha$ convergence for different $\lambda$')
ax.legend(fontsize=10)

ax = axes[1]
for lam, col in zip(lambdas, colors_lam):
    E_err = np.abs(hist_lam[lam]['energy'] - EXACT_E0)
    ax.semilogy(E_err, color=col, lw=1.8, label=rf'$\lambda={lam:.0e}$')
ax.set_xlabel('Iteration'); ax.set_ylabel(r'$|\langle E\rangle - E_0|$')
ax.set_title(r'Energy error for different regularisation $\lambda$')
ax.legend(fontsize=10)

plt.suptitle(r'Effect of regularisation parameter $\lambda$ on SR convergence',
             fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.3  Multi-parameter extension: the full $S$ matrix
#
# To illustrate the full SR linear system for $p > 1$ parameters, we extend the ansatz to a **two-parameter Gaussian**:
#
# $$\Psi_{\alpha_1,\alpha_2}(\mathbf{r}_1,\ldots,\mathbf{r}_N) = \exp\!\left(-\alpha_1\sum_{i=1}^{N}r_i^2 - \alpha_2\sum_{i=1}^{N}r_i^4\right).$$
#
# For this ansatz the logarithmic derivatives are
#
# $$O_1(x) = -\sum_i r_i^2, \qquad O_2(x) = -\sum_i r_i^4,$$
#
# and the metric matrix is
#
# $$S = \begin{pmatrix}
# \langle O_1^2\rangle-\langle O_1\rangle^2 &
# \langle O_1 O_2\rangle-\langle O_1\rangle\langle O_2\rangle \\
# \langle O_1 O_2\rangle-\langle O_1\rangle\langle O_2\rangle &
# \langle O_2^2\rangle-\langle O_2\rangle^2
# \end{pmatrix}.$$
#
# The exact minimum is $\boldsymbol{\alpha}^* = (0.5, 0)$ (the $r^4$ term vanishes in the exact ground state).  This example demonstrates how the $2\times 2$ SR linear system is assembled and solved, and verifies that $S$ is indeed positive semidefinite.

# %%
# ── Two-parameter ansatz: Psi = exp(-a1*sum r^2 - a2*sum r^4) ───────────────

def log_psi_2p(x, alpha):
    """Log-wave-function for the two-parameter ansatz."""
    a1, a2 = alpha
    r2 = np.sum(x**2)
    r4 = np.sum(x**4)
    return -a1 * r2 - a2 * r4


def local_energy_2p(x, alpha):
    """Local energy for the two-parameter ansatz (via finite differences)."""
    a1, a2  = alpha
    N, d    = x.shape
    r2      = np.sum(x**2)
    r4      = np.sum(x**4)
    # Analytic: kinetic energy from -1/2 nabla^2 psi / psi
    # For phi = -a1 r^2 - a2 r^4:
    # nabla_i^2 phi = -2*a1*d - 4*a2*(d+2)*r_i^2
    # (nabla_i phi)^2 = (2*a1*r_i + 4*a2*r_i^3)^2
    # E_kin = sum_i [ -1/2 * nabla_i^2 phi - 1/2 * (nabla_i phi)^2 ]
    kinetic = 0.0
    for i in range(N):
        ri2       = np.sum(x[i]**2)
        lap_phi   = -2*a1*d - 4*a2*(d + 2)*ri2
        grad_phi2 = np.sum((2*a1*x[i] + 4*a2*x[i]**3)**2)
        kinetic  += -0.5 * lap_phi - 0.5 * grad_phi2
    potential = 0.5 * r2
    return kinetic + potential


def log_deriv_2p(x):
    """Logarithmic derivatives [O_1, O_2] for the two-parameter ansatz."""
    return np.array([-np.sum(x**2), -np.sum(x**4)])   # shape (2,)


def sr_step_2p(alpha, N_samples=3000, dtau=0.05, lam=1e-3,
               step_size=0.5):
    """One SR step for the two-parameter ansatz.

    Returns updated alpha, energy, S matrix (2x2), g vector (2,).
    """
    # Sample from |Psi|^2 via Metropolis
    x_curr = np.random.randn(N_PARTICLES, DIM) * 0.5
    lp_cur = log_psi_2p(x_curr, alpha)
    samples = []
    for _ in range(2000 + N_samples):    # 2000 equilibration
        x_prop = x_curr + step_size * np.random.randn(N_PARTICLES, DIM)
        lp_new = log_psi_2p(x_prop, alpha)
        if np.log(np.random.uniform()) < 2*(lp_new - lp_cur):
            x_curr, lp_cur = x_prop, lp_new
        if len(samples) < N_samples:
            samples.append(x_curr.copy())
        else:
            pass  # done after equilibration
    # correct: collect only after equil
    x_curr = np.random.randn(N_PARTICLES, DIM) * 0.5
    lp_cur = log_psi_2p(x_curr, alpha)
    configs = []
    for step in range(2000 + N_samples):
        x_prop = x_curr + step_size * np.random.randn(N_PARTICLES, DIM)
        lp_new = log_psi_2p(x_prop, alpha)
        if np.log(np.random.uniform()) < 2*(lp_new - lp_cur):
            x_curr, lp_cur = x_prop, lp_new
        if step >= 2000:
            configs.append(x_curr.copy())

    # Vectorise
    O_all  = np.array([log_deriv_2p(c) for c in configs])   # (Ns, 2)
    EL_all = np.array([local_energy_2p(c, alpha) for c in configs])  # (Ns,)

    O_mean  = O_all.mean(axis=0)    # (2,)
    E_mean  = EL_all.mean()

    # S matrix (2x2):  S_ij = <O_i O_j> - <O_i><O_j>
    S_mat = (O_all[:, :, None] * O_all[:, None, :]).mean(axis=0) \
            - np.outer(O_mean, O_mean)   # (2, 2)

    # g vector (2,):  g_i = <O_i E_loc> - <O_i><E_loc>
    g_vec = (O_all * EL_all[:, None]).mean(axis=0) - O_mean * E_mean  # (2,)

    # Solve (S + lam I) d_alpha = -dtau g
    S_reg   = S_mat + lam * np.eye(2)
    d_alpha = solve(S_reg, -dtau * g_vec)
    alpha_new = alpha + d_alpha
    alpha_new[0] = max(alpha_new[0], 1e-4)   # keep a1 > 0

    return alpha_new, E_mean, S_mat, g_vec


# ── Run 2-parameter SR ────────────────────────────────────────────────────────
alpha2p  = np.array([0.8, 0.1])   # start away from (0.5, 0)
traj_2p  = []

print('Running 2-parameter SR  (alpha* = [0.5, 0.0]) ...')
for it in range(80):
    alpha2p, E_m, S_m, g_m = sr_step_2p(alpha2p, N_samples=3000)
    traj_2p.append((alpha2p.copy(), E_m, np.linalg.eigvalsh(S_m)))
    if it % 20 == 0 or it == 79:
        print(f'  iter {it+1:3d}: alpha={alpha2p},  E={E_m:.5f}')

alphas_2p = np.array([t[0] for t in traj_2p])
energies_2p = np.array([t[1] for t in traj_2p])
eigenvalues_2p = np.array([t[2] for t in traj_2p])

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

ax = axes[0]
ax.plot(alphas_2p[:, 0], color='steelblue', lw=2, label=r'$\alpha_1$')
ax.plot(alphas_2p[:, 1], color='tomato',    lw=2, label=r'$\alpha_2$')
ax.axhline(0.5, color='steelblue', ls=':', lw=1.3)
ax.axhline(0.0, color='tomato',    ls=':', lw=1.3)
ax.set_xlabel('Iteration'); ax.set_ylabel(r'$\alpha$')
ax.set_title('Two-parameter SR: parameter convergence')
ax.legend()

ax = axes[1]
ax.semilogy(np.abs(energies_2p - EXACT_E0), color='darkorchid', lw=2)
ax.set_xlabel('Iteration')
ax.set_ylabel(r'$|\langle E\rangle - E_0|$')
ax.set_title('Two-parameter SR: energy error')

ax = axes[2]
ax.semilogy(eigenvalues_2p[:, 0], color='steelblue', lw=2,
            label=r'$\lambda_\mathrm{min}(S)$')
ax.semilogy(eigenvalues_2p[:, 1], color='tomato',    lw=2,
            label=r'$\lambda_\mathrm{max}(S)$')
ax.set_xlabel('Iteration')
ax.set_ylabel('Eigenvalue of $S$')
ax.set_title(r'$S$ matrix eigenvalues (positive semidefinite check)')
ax.legend()

plt.suptitle(r'Two-parameter ansatz: $\Psi = \exp(-\alpha_1 \sum r_i^2 '
             r'- \alpha_2 \sum r_i^4)$', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.4  Geometry of the variational manifold
#
# The metric $S_{11}$ determines the curvature of the Fisher information geometry at each $\alpha$.  Near the minimum $\alpha^*=0.5$, $S_{11}$ reaches a plateau that sets the natural learning rate.  We compare $1/(S_{11}+\lambda)$ (the SR effective learning rate) with the plain GD rate $\eta$ across the full $\alpha$ range.

# %%
alphas_geom = np.linspace(0.2, 1.2, 40)
S_vals, g_vals, eff_lr = [], [], []

lam_geom = 1e-3
for a in alphas_geom:
    _, _, S_11, g_1, _ = vmc_estimate(a, N_samples=5000)
    S_vals .append(S_11)
    g_vals .append(g_1)
    eff_lr .append(1.0 / (S_11 + lam_geom))

S_vals  = np.array(S_vals)
g_vals  = np.array(g_vals)
eff_lr  = np.array(eff_lr)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

ax = axes[0]
ax.plot(alphas_geom, S_vals, color='darkorchid', lw=2)
ax.axvline(EXACT_ALPHA, color='k', ls=':', lw=1.5)
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel(r'$S_{11}(\alpha)$')
ax.set_title(r'Fisher metric $S_{11}$ vs $\alpha$')

ax = axes[1]
ax.plot(alphas_geom, g_vals, color='steelblue', lw=2)
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.axvline(EXACT_ALPHA, color='k', ls=':', lw=1.5)
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel(r'$g_1(\alpha)$')
ax.set_title(r'Force $g_1$ vs $\alpha$ (zero at minimum)')

ax = axes[2]
ax.plot(alphas_geom, eff_lr,       color='steelblue', lw=2,
        label=r'SR  $1/(S_{11}+\lambda)$')
ax.axhline(0.05, color='tomato', lw=2, ls='--', label=r'GD  $\eta=0.05$')
ax.axvline(EXACT_ALPHA, color='k', ls=':', lw=1.5)
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel('Effective learning rate')
ax.set_title('SR adapts learning rate to manifold geometry')
ax.legend(fontsize=10)

plt.suptitle(
    r'Geometry of the variational manifold: $N='+str(N_PARTICLES)+r'$, $d='+str(DIM)+r'$',
    fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7.5  Numerical Verification of the Fisher Information
#
# We now verify computationally the key identity $F_{11} = 4S_{11}$,
# the KL-curvature interpretation of the Fisher metric, and the
# Cramér–Rao bound established in Section~4b.

# %%
# ═══════════════════════════════════════════════════════════════════════════
# Numerical verification: F = 4 S and KL curvature
# ═══════════════════════════════════════════════════════════════════════════

def fisher_matrix_exact(alpha, N=N_PARTICLES, d=DIM):
    """Exact Fisher information matrix F_11 = 4 S_11 for the Gaussian ansatz.

    For Psi = exp(-alpha * sum r^2), the score is
        s_1(x) = 2 O_1(x) - 2 <O_1>  =  2*(-sum r^2) - 2*(-N*d/(2*alpha))
               = -2*sum r^2 + N*d/alpha.

    The Fisher information is
        F_11 = E_p[s_1^2] = Var_p(s_1) = 4 * Var_p(O_1) = 4 * S_11.

    For the d-dimensional isotropic Gaussian with scale 1/(2*alpha):
        E_p[sum r^2]       = N*d / (2*alpha)
        E_p[(sum r^2)^2]   = (N*d / (2*alpha))^2  +  N*d / (2*alpha)^2
        Var_p(sum r^2)     = N*d / (2*alpha)^2
        S_11               = N*d / (4*alpha^2)
        F_11 = 4*S_11      = N*d / alpha^2
    """
    S11_exact = N * d / (4.0 * alpha**2)
    F11_exact = 4.0 * S11_exact
    return S11_exact, F11_exact


def kl_divergence_gaussian(alpha, dalpha, N=N_PARTICLES, d=DIM, N_samples=8000):
    """Estimate KL(p(alpha) || p(alpha+dalpha)) by Monte Carlo.

    Uses the identity KL(p||q) = E_p[log p - log q].
    For real Gaussians this is available analytically:
        KL = N*d/2 * [dalpha/alpha - ln(1+dalpha/alpha) ]
    which to 2nd order in dalpha gives (1/2)*F_11*dalpha^2 = (1/2)*N*d/alpha^2 * dalpha^2.
    We compare both.
    """
    alpha2 = alpha + dalpha
    # Analytic KL for N*d independent Gaussians N(0, 1/(2*alpha))
    # vs N(0, 1/(2*alpha2))
    # KL(N(0,s1^2) || N(0,s2^2)) = log(s2/s1) + s1^2/(2*s2^2) - 1/2
    # with s1^2 = 1/(2*alpha), s2^2 = 1/(2*alpha2), per component per particle
    s1sq = 1.0 / (2.0 * alpha)
    s2sq = 1.0 / (2.0 * alpha2)
    kl_1d = 0.5 * (np.log(s2sq / s1sq) + s1sq / s2sq - 1.0)
    kl_analytic = N * d * kl_1d
    kl_quadratic = 0.5 * (N * d / alpha**2) * dalpha**2   # 2nd-order approximation
    return kl_analytic, kl_quadratic


# ── Verify F = 4S over a range of alpha ──────────────────────────────────────
alphas_check = np.linspace(0.25, 1.5, 20)
S11_mc, F11_mc = [], []
S11_ex, F11_ex = [], []

print('Verifying  F_11 = 4 * S_11  by Monte Carlo sampling')
print(f'{"alpha":>8}  {"S_11 (MC)":>12}  {"S_11 (exact)":>12}'
      f'  {"F_11 = 4*S (MC)":>16}  {"F_11 (exact)":>12}  {"ratio F/S":>10}')
print('-' * 85)

for a in alphas_check:
    _, _, S_mc, _, _ = vmc_estimate(a, N_samples=6000)
    S_ex, F_ex       = fisher_matrix_exact(a)
    F_mc             = 4.0 * S_mc
    S11_mc .append(S_mc)
    F11_mc .append(F_mc)
    S11_ex .append(S_ex)
    F11_ex .append(F_ex)

S11_mc = np.array(S11_mc); F11_mc = np.array(F11_mc)
S11_ex = np.array(S11_ex); F11_ex = np.array(F11_ex)

for a, s_mc, s_ex, f_mc, f_ex in zip(
        alphas_check[::4], S11_mc[::4], S11_ex[::4], F11_mc[::4], F11_ex[::4]):
    print(f'{a:8.3f}  {s_mc:12.5f}  {s_ex:12.5f}'
          f'  {f_mc:16.5f}  {f_ex:12.5f}  {f_mc/s_mc:10.4f}')

print()
print(f'Max relative error |S_MC - S_exact| / S_exact: '
      f'{np.max(np.abs(S11_mc - S11_ex) / S11_ex):.4f}')

# %%
# ── Visualise the Fisher–Rao geometry and KL curvature ───────────────────────
dalpha_vals = np.linspace(-0.3, 0.3, 200)
alpha_ref   = 0.8

# Exact KL and quadratic approximation
kl_exact_arr  = np.array([kl_divergence_gaussian(alpha_ref, da)[0] for da in dalpha_vals])
kl_approx_arr = np.array([kl_divergence_gaussian(alpha_ref, da)[1] for da in dalpha_vals])

# Exact Fisher and SR S-matrix over alpha range
F_exact_arr = np.array([fisher_matrix_exact(a)[1] for a in alphas_check])

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# ── Panel 1: S_11 vs alpha (MC vs exact) ─────────────────────────────────────
ax = axes[0]
ax.plot(alphas_check, S11_ex, color='steelblue', lw=2.5,
        label=r'Exact $S_{11} = Nd/(4\alpha^2)$')
ax.scatter(alphas_check, S11_mc, color='tomato', s=45, zorder=5,
           label='MC estimate')
ax.axvline(EXACT_ALPHA, color='k', ls=':', lw=1.5,
           label=r'$\alpha^*=0.5$')
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel(r'$S_{11}(\alpha)$')
ax.set_title(r'SR metric $S_{11} = F_{11}/4$ (exact and MC)')
ax.legend(fontsize=9)

# ── Panel 2: KL divergence curvature ─────────────────────────────────────────
ax = axes[1]
ax.plot(dalpha_vals, kl_exact_arr,  color='steelblue', lw=2.5,
        label=r'Exact $D_\mathrm{KL}$')
ax.plot(dalpha_vals, kl_approx_arr, color='tomato',    lw=2.0, ls='--',
        label=r'$\frac{1}{2}F_{11}(d\alpha)^2$  (2nd order)')
ax.set_xlabel(r'$d\alpha$')
ax.set_ylabel(r'$D_{\rm KL}(p(\alpha) \| p(\alpha + d\alpha))$')
ax.set_title(rf'KL curvature at $\alpha={alpha_ref}$,  $F_{{11}}={fisher_matrix_exact(alpha_ref)[1]:.2f}$')
ax.legend(fontsize=9)

# ── Panel 3: Fisher info F_11 = 4*S_11 vs alpha ──────────────────────────────
ax = axes[2]
ax.plot(alphas_check, F_exact_arr,      color='darkorchid', lw=2.5,
        label=r'$F_{11}=Nd/\alpha^2$')
ax.plot(alphas_check, 4.0 * S11_mc,    color='tomato',     lw=2.0, ls='--',
        label=r'$4\,S_{11}$ (MC)')
ax.plot(alphas_check, 1.0 / F_exact_arr, color='steelblue', lw=2.0, ls=':',
        label=r'$(F_{11})^{-1}$ (SR effective LR)')
ax.axvline(EXACT_ALPHA, color='k', ls=':', lw=1.5)
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel('Value')
ax.set_title(r'Fisher info $F_{11}=4S_{11}$ and effective LR')
ax.legend(fontsize=9)

plt.suptitle(
    r'Fisher Information Geometry: $N='+str(N_PARTICLES)+r'$ bosons, $d='+str(DIM)+r'$',
    fontsize=13)
plt.tight_layout()
plt.show()

# Print Cramer-Rao bound at alpha*
_, F_opt = fisher_matrix_exact(EXACT_ALPHA)
print(f'At alpha* = {EXACT_ALPHA}:')
print(f'  F_11         = {F_opt:.4f}')
print(f'  CR bound (N_s=4000): sigma_alpha >= {1.0/np.sqrt(4000*F_opt):.6f}')
print(f'  Meaning: with 4000 samples, alpha cannot be estimated')
print(f'  more precisely than ~{1/np.sqrt(4000*F_opt):.2e} regardless of method.')

# %% [markdown]
# ---
# ## 8  Exercises
#
# ### Analytical
#
# 1. **Exact energy curve.** Derive the analytic expression $E(\alpha) = \frac{Nd}{2}\left(\alpha + \frac{1}{4\alpha}\right)$ by computing $\langle\Psi_\alpha|H|\Psi_\alpha\rangle/\langle\Psi_\alpha|\Psi_\alpha\rangle$ using Gaussian integrals. Verify that its minimum is at $\alpha^* = 1/2$ and equals $E_0 = Nd/2$.
#
# 2. **Local energy.** Starting from $H = \sum_i(-\frac{1}{2}\nabla_i^2 +\frac{1}{2}r_i^2)$, derive the analytic local energy formula
# $$E_\mathrm{loc}(x) = Nd\alpha + \left(\frac{1}{2}-2\alpha^2\right)\sum_i r_i^2$$
# used in the code. Verify that at $\alpha=1/2$ this reduces to $E_\mathrm{loc}=Nd/2$ (a constant, consistent with $\Psi_{1/2}$ being the exact ground state).
#
# 3. **S matrix for the two-parameter ansatz.** For $\Psi = \exp(-\alpha_1\sum r_i^2 - \alpha_2\sum r_i^4)$, derive $S_{12} = \langle O_1 O_2\rangle - \langle O_1\rangle\langle O_2\rangle$ analytically using $d$-dimensional Gaussian integrals with the Wick theorem. Check whether $S$ is positive definite at $(\alpha_1,\alpha_2)=(0.5,0)$.
#
# 4. **Natural gradient reparameterisation invariance.** Let $\beta = f(\alpha)$ be a smooth invertible reparameterisation. Show that the natural gradient update expressed in $\beta$-coordinates gives the same parameter trajectory as in $\alpha$-coordinates, while plain gradient descent does not have this property.
#
# ### Computational
#
# 5. **Dimension and particle-number scaling.** Run the SR optimiser for $(N,d)\in\{(1,1),(2,1),(1,3),(3,3),(5,3)\}$. Tabulate the number of SR iterations needed to reach $|E-E_0|<10^{-2}$. Does SR performance change with $N$ or $d$?
#
# 6. **Step-size tuning.** The Metropolis step size $\delta$ controls the acceptance rate. Write an adaptive version of `metropolis_sampler` that adjusts $\delta$ every 100 steps to keep the acceptance rate in $[0.4, 0.6]$. Compare the variance of $S_{11}$ and $g_1$ estimates with fixed and adaptive step sizes.
#
# 7. **SR vs Adam.** Implement the Adam optimiser for VMC (keeping the same $g_1$ force estimator but replacing $S^{-1}$ with Adam's adaptive second-moment estimate). Compare convergence speed and final energy accuracy with SR and plain GD.
#
# 8. **Block averaging and autocorrelation.** Monte Carlo samples from a Markov chain are correlated. Implement a block-averaging procedure to estimate the true statistical error on $\langle E_\mathrm{loc}\rangle$. How does the integrated autocorrelation time depend on the step size $\delta$ and the parameter $\alpha$?
#
# 9. **Regularisation schedule.** Instead of a fixed $\lambda$, implement a decaying schedule $\lambda_t = \lambda_0 / (1 + t/T)$. Find values of $\lambda_0$ and $T$ that give faster convergence than the fixed-$\lambda$ case.
#
# 10. **Interacting bosons.** Add a Jastrow factor
# $$J(\mathbf{r}_1,\ldots,\mathbf{r}_N) = \exp\!\left(-\beta\sum_{i<j}\frac{1}{r_{ij}^2+a^2}\right)$$
# to the Gaussian ansatz, where $r_{ij} = |\mathbf{r}_i-\mathbf{r}_j|$, $a$ is a hard-core parameter, and $\beta$ is a new variational parameter. Extend the SR algorithm to handle both $\alpha$ and $\beta$ simultaneously using the full $2\times2$ SR linear system. (Use finite differences for the local energy if the analytic expression becomes unwieldy.)
#
# ### Fisher Information and Natural Gradient
#
# 11. **Hessian form of the Fisher information.** Prove that $F_{ij} = -\mathbb{E}_p[\partial^2\ln p/\partial\alpha_i\partial\alpha_j]$ starting from the score-covariance definition, using integration by parts and the normalisation condition $\int p\,dx=1$. At which step does regularity (interchange of differentiation and integration) matter?
#
# 12. **Analytic Fisher information for the Gaussian ansatz.** Using $d$-dimensional Gaussian integration, derive the exact result
# $$F_{11}(\alpha) = \frac{Nd}{\alpha^2}$$
# directly from $F_{11}=\mathbb{E}_p[s_1^2]$ with $s_1(x)=-2\sum_i r_i^2+Nd/\alpha$. Verify that this matches $4S_{11}$ as derived in Section~4b.
#
# 13. **Cramér–Rao bound in practice.** The Cramér–Rao bound says $\mathrm{Var}(\hat\alpha)\geq 1/(N_s F_{11})$. Run the SR optimiser with $N_s\in\{500,1000,2000,4000,8000\}$ samples per iteration and plot the variance of $\alpha$ over the last 20 iterations against $1/(N_s F_{11}(\alpha^*))$. Does the MC estimator saturate the bound?
#
# 14. **KL divergence and step-size choice.** For the Gaussian ansatz the exact KL divergence is available analytically. Choose $\delta\tau$ such that each SR step satisfies $D_\mathrm{KL}(p(\boldsymbol{\alpha})\|p(\boldsymbol{\alpha}+\delta\boldsymbol{\alpha}))\leq 0.01$ at every iteration (trust-region SR). Implement this adaptive $\delta\tau$ and compare convergence with fixed step sizes $\delta\tau\in\{0.01,0.05,0.1\}$.
#
# 15. **Natural gradient vs Adam.** Adam's diagonal second-moment estimate $\hat v_k\approx g_k^2$ approximates $F_{kk}$ (the diagonal of the FIM). For the single-parameter Gaussian ansatz verify numerically that Adam's effective learning rate $\eta/\sqrt{\hat v + \epsilon}$ converges to $\eta/\sqrt{F_{11}}\approx\eta\alpha/(Nd)^{1/2}$ near the optimum. In which sense is Adam an approximation to the natural gradient?
